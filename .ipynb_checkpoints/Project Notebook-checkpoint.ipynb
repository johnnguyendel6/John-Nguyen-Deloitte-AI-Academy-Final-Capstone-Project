# %%
#Import Necessary Libraries and Packages
import numpy as np 
import pandas as pd  
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

### Comparing Tech Revenue to Profit

#Read the Fortune 100 2021 CSV File
df = pd.read_csv("Consolidated 2021 Fortune 100 Company Data.csv", header=0)

#Drop Unnecessary Columns
df = df.drop([' Rank ',' Name ',' Source '], axis = 1)

#Filter Tech Data
df = df[df[" Group "] == "Yes"]

#Drop Group "Yes"
df = df.drop([' Group '], axis = 1)


#Columns to Be Analyzed
Independent_x = df[' Revenue ']
Dependent_y = df[' Profit ']


#Remove Dollar Signs, Commas, and Spaces From Strings
Independent_x = df[' Revenue '] = df[' Revenue '].str.replace('$', '')
Independent_x = df[' Revenue '] = df[' Revenue '].str.replace(' ', '')
Independent_x = df[' Revenue '] = df[' Revenue '].str.replace(',', '')

Dependent_y = df[' Profit '] = df[' Profit '].str.replace('$', '')
Dependent_y = df[' Profit '] = df[' Profit '].str.replace(' ', '')
Dependent_y = df[' Profit '] = df[' Profit '].str.replace(',', '')
Dependent_y = df[' Profit '] = df[' Profit '].str.replace('(', '-')
Dependent_y = df[' Profit '] = df[' Profit '].str.replace(')', '')


#Convert Data Type to a Float
Independent_x = Independent_x.astype(float)
Dependent_y = Dependent_y.astype(float)

#Find Size Of DataFrame
sizeOfData = len(df[' Revenue '])


#Take the Average of the Panda DataFrame For Tech
revenueMean_2021 = Independent_x.mean()
profitMean_2021 = Dependent_y.mean()

#Read the Fortune 100 2022 CSV File
df2 = pd.read_csv("Consolidated 2022 Fortune 100 Company Data.csv", header=0)

#Drop Unnecessary Columns
df2 = df2.drop([" Rank ", " Name "," Source "], axis = 1)

#Filter Tech Data
df2 = df2[df2[' Tech '] == "Yes"]

#Drop Group "Yes"
df2 = df2.drop([' Tech '], axis = 1)


#Columns to Be Analyzed
Independent_x2 = df2[' Revenue ']
Dependent_y2 = df2[' Profit ']


#Remove Dollar Signs, Commas, and Spaces From Strings
Independent_x2 = df2[' Revenue '] = df2[' Revenue '].str.replace('$', '')
Independent_x2 = df2[' Revenue '] = df2[' Revenue '].str.replace(' ', '')
Independent_x2 = df2[' Revenue '] = df2[' Revenue '].str.replace(',', '')

Dependent_y2 = df2[' Profit '] = df2[' Profit '].str.replace('$', '')
Dependent_y2 = df2[' Profit '] = df2[' Profit '].str.replace(' ', '')
Dependent_y2 = df2[' Profit '] = df2[' Profit '].str.replace(',', '')
Dependent_y2 = df2[' Profit '] = df2[' Profit '].str.replace('(', '-')
Dependent_y2 = df2[' Profit '] = df2[' Profit '].str.replace(')', '')

#Convert Data Type to a Float
Independent_x2 = Independent_x2.astype(float)
Dependent_y2 = Dependent_y2.astype(float)

#Find Size of PandaFrame
sizeOfData_2 = len(df2[' Revenue '])

#Take the Average of the Panda DataFrame For Tech
revenueMean_2022 = Independent_x2.mean()
profitMean_2022 = Dependent_y2.mean()

#print(revenueMean_2022)
#print(profitMean_2022)

array_Revenue = []
array_Profit = []

array_Revenue.append(revenueMean_2021)
array_Revenue.append(revenueMean_2022)
array_Revenue = np.array(array_Revenue).reshape((-1,1))


array_Profit.append(profitMean_2021)
array_Profit.append(profitMean_2022)
array_Profit = np.array(array_Profit)

#Implement the Linear Regression Function
regressionModel = LinearRegression()


#Fit the Model
regressionModel.fit(array_Revenue,array_Profit)

#Predict Values
regressionModel.predict(array_Revenue)

#Coeficent of Determination(R2 Percentage)
score = regressionModel.score(array_Revenue,array_Profit)

#Y intercept
intercept = regressionModel.intercept_
print(intercept)

#Slope
slope = regressionModel.coef_
print(slope)

print(Independent_x2)

x = np.linspace(-1000,600000,24)
y = (slope*x+intercept)

print(r2_score(Dependent_y, y))

plt.scatter(Independent_x,Dependent_y, label=str(2021))
plt.scatter(Independent_x2,Dependent_y2, label=str(2022))
plt.plot(array_Revenue,regressionModel.predict(array_Revenue))
plt.plot(x,y)
plt.title("Revenue Against Profits 2021-2022 Tech")
plt.xlabel("Revenues in Millions")
plt.ylabel("Profits in Millions")
plt.annotate('R2 score = %(score)d  ' %{"score":score}, xy = (0,155000))
plt.legend(loc = 0, numpoints = 1, ncol = 2, fontsize = 8)
plt.show()
# Out:
# -22505.63874271099
# [0.32538448]
# 1     469822.0
# 2     365817.0
# 7     257637.0
# 8     238228.0
# 12    168864.0
# 13    168088.0
# 22    133613.0
# 26    117929.0
# 27    116385.0
# 30    106995.0
# 45     79024.0
# 47     74196.0
# 48     72344.0
# 54     67044.0
# 57     64388.0
# 58     63487.0
# 59     62286.0
# 64     53823.0
# 68     51682.0
# 73     49818.0
# 90     40479.0
# 91     39211.0
# Name:  Revenue , dtype: float64
# -32.32194861721142

# %%
### Comparing Non-Tech Revenue to Profit


#Import Necessary Libraries and Packages
import numpy as np 
import pandas as pd  
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

#Read the Fortune 100 2021 CSV File
df = pd.read_csv("Consolidated 2021 Fortune 100 Company Data.csv", header=0)

#Drop Unnecessary Columns
df = df.drop([' Rank ',' Name ',' Source '], axis = 1)

#Filter Tech Data
df = df[df[" Group "] == "No"]

#Drop Group "Yes"
df = df.drop([' Group '], axis = 1)


#Columns to Be Analyzed
Independent_x = df[' Revenue ']
Dependent_y = df[' Profit ']


#Remove Dollar Signs, Commas, and Spaces From Strings
Independent_x = df[' Revenue '] = df[' Revenue '].str.replace('$', '')
Independent_x = df[' Revenue '] = df[' Revenue '].str.replace(' ', '')
Independent_x = df[' Revenue '] = df[' Revenue '].str.replace(',', '')

Dependent_y = df[' Profit '] = df[' Profit '].str.replace('$', '')
Dependent_y = df[' Profit '] = df[' Profit '].str.replace(' ', '')
Dependent_y = df[' Profit '] = df[' Profit '].str.replace(',', '')
Dependent_y = df[' Profit '] = df[' Profit '].str.replace('(', '-')
Dependent_y = df[' Profit '] = df[' Profit '].str.replace(')', '')


#Convert Data Type to a Float
Independent_x = Independent_x.astype(float)
Dependent_y = Dependent_y.astype(float)

#Take the Average of the Panda DataFrame For Tech
revenueMean_2021 = Independent_x.mean()
profitMean_2021 = Dependent_y.mean()

#Read the Fortune 100 2022 CSV File
df2 = pd.read_csv("Consolidated 2022 Fortune 100 Company Data.csv", header=0)

#Drop Unnecessary Columns
df2 = df2.drop([" Rank ", " Name "," Source "], axis = 1)

#Filter Tech Data
df2 = df2[df2[' Tech '] == "No"]

#Drop Group "Yes"
df2 = df2.drop([' Tech '], axis = 1)


#Columns to Be Analyzed
Independent_x2 = df2[' Revenue ']
Dependent_y2 = df2[' Profit ']


#Remove Dollar Signs, Commas, and Spaces From Strings
Independent_x2 = df2[' Revenue '] = df2[' Revenue '].str.replace('$', '')
Independent_x2 = df2[' Revenue '] = df2[' Revenue '].str.replace(' ', '')
Independent_x2 = df2[' Revenue '] = df2[' Revenue '].str.replace(',', '')

Dependent_y2 = df2[' Profit '] = df2[' Profit '].str.replace('$', '')
Dependent_y2 = df2[' Profit '] = df2[' Profit '].str.replace(' ', '')
Dependent_y2 = df2[' Profit '] = df2[' Profit '].str.replace(',', '')
Dependent_y2 = df2[' Profit '] = df2[' Profit '].str.replace('(', '-')
Dependent_y2 = df2[' Profit '] = df2[' Profit '].str.replace(')', '')

#Convert Data Type to a Float
Independent_x2 = Independent_x2.astype(float)
Dependent_y2 = Dependent_y2.astype(float)

#Take the Average of the Panda DataFrame For Tech
revenueMean_2022 = Independent_x2.mean()
profitMean_2022 = Dependent_y2.mean()

#print(revenueMean_2022)
#print(profitMean_2022)

array_Revenue = []
array_Profit = []

array_Revenue.append(revenueMean_2021)
array_Revenue.append(revenueMean_2022)
array_Revenue = np.array(array_Revenue).reshape((-1,1))


array_Profit.append(profitMean_2021)
array_Profit.append(profitMean_2022)
array_Profit = np.array(array_Profit)

#Implement the Linear Regression Function
regressionModel = LinearRegression()


#Fit the Model
print(regressionModel.fit(array_Revenue,array_Profit))

#Predict Values
print(regressionModel.predict(array_Revenue))

#Coeficent of Determination
#print(regressionModel.score(array_Revenue,array_Profit))

#Y intercept
intercept = regressionModel.intercept_
#print(intercept)

#Slope
slope = regressionModel.coef_
#print(slope)

print(Independent_x2)

x = np.linspace(-1000,600000,100)
y = (slope*x+intercept)

plt.scatter(Independent_x,Dependent_y, label=str(2021))
plt.scatter(Independent_x2,Dependent_y2, label=str(2022))
plt.plot(array_Revenue,regressionModel.predict(array_Revenue))
plt.plot(x,y)
plt.title("Revenue Against Profits 2021-2022 Non-Tech")
plt.xlabel("Revenues in Millions")
plt.ylabel("Profits in Millions")
plt.annotate('R2 score = %(score)d  ' %{"score":score}, xy = (0,155000))
plt.legend(loc = 0, numpoints = 1, ncol = 2, fontsize = 8)
plt.show()
# Out:
# LinearRegression()
# [4020.44736842 9298.63717949]
# 0     572754.0
# 3     292111.0
# 4     287597.0
# 5     285640.0
# 6     276094.0
#         ...
# 95     37469.6
# 96     36751.2
# 97     36483.9
# 98     36347.0
# 99     35899.5
# Name:  Revenue , Length: 78, dtype: float64

# %%
### Comparing Tech Expenses to Profit

#Import Necessary Libraries and Packages
import numpy as np 
import pandas as pd  
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

#Read the Fortune 100 2021 CSV File
df = pd.read_csv("Consolidated 2021 Fortune 100 Company Data.csv", header=0)

#Drop Unnecessary Columns
df = df.drop([' Rank ',' Name ',' Source '], axis = 1)

#Filter Tech Data
df = df[df[" Group "] == "Yes"]

#Drop Group "Yes"
df = df.drop([' Group '], axis = 1)


#Columns to Be Analyzed
Independent_x = df[' Expenses ']
Dependent_y = df[' Profit ']


#Remove Dollar Signs, Commas, and Spaces From Strings
Independent_x = df[' Expenses '] = df[' Expenses '].str.replace('$', '')
Independent_x = df[' Expenses '] = df[' Expenses '].str.replace(' ', '')
Independent_x = df[' Expenses '] = df[' Expenses '].str.replace(',', '')

Dependent_y = df[' Profit '] = df[' Profit '].str.replace('$', '')
Dependent_y = df[' Profit '] = df[' Profit '].str.replace(' ', '')
Dependent_y = df[' Profit '] = df[' Profit '].str.replace(',', '')
Dependent_y = df[' Profit '] = df[' Profit '].str.replace('(', '-')
Dependent_y = df[' Profit '] = df[' Profit '].str.replace(')', '')


#Convert Data Type to a Float
Independent_x = Independent_x.astype(float)
Dependent_y = Dependent_y.astype(float)

#Take the Average of the Panda DataFrame For Tech
revenueMean_2021 = Independent_x.mean()
profitMean_2021 = Dependent_y.mean()

#Read the Fortune 100 2022 CSV File
df2 = pd.read_csv("Consolidated 2022 Fortune 100 Company Data.csv", header=0)

#Drop Unnecessary Columns
df2 = df2.drop([" Rank ", " Name "," Source "], axis = 1)

#Filter Tech Data
df2 = df2[df2[' Tech '] == "Yes"]

#Drop Group "Yes"
df2 = df2.drop([' Tech '], axis = 1)


#Columns to Be Analyzed
Independent_x2 = df2[' Expenses ']
Dependent_y2 = df2[' Profit ']


#Remove Dollar Signs, Commas, and Spaces From Strings
Independent_x2 = df2[' Expenses '] = df2[' Expenses '].str.replace('$', '')
Independent_x2 = df2[' Expenses '] = df2[' Expenses '].str.replace(' ', '')
Independent_x2 = df2[' Expenses '] = df2[' Expenses '].str.replace(',', '')

Dependent_y2 = df2[' Profit '] = df2[' Profit '].str.replace('$', '')
Dependent_y2 = df2[' Profit '] = df2[' Profit '].str.replace(' ', '')
Dependent_y2 = df2[' Profit '] = df2[' Profit '].str.replace(',', '')
Dependent_y2 = df2[' Profit '] = df2[' Profit '].str.replace('(', '-')
Dependent_y2 = df2[' Profit '] = df2[' Profit '].str.replace(')', '')

#Convert Data Type to a Float
Independent_x2 = Independent_x2.astype(float)
Dependent_y2 = Dependent_y2.astype(float)

#Take the Average of the Panda DataFrame For Tech
revenueMean_2022 = Independent_x2.mean()
profitMean_2022 = Dependent_y2.mean()

print(revenueMean_2022)
print(profitMean_2022)

array_Revenue = []
array_Profit = []

array_Revenue.append(revenueMean_2021)
array_Revenue.append(revenueMean_2022)
array_Revenue = np.array(array_Revenue).reshape((-1,1))


array_Profit.append(profitMean_2021)
array_Profit.append(profitMean_2022)
array_Profit = np.array(array_Profit)

#Implement the Linear Regression Function
regressionModel = LinearRegression()


#Fit the Model
print(regressionModel.fit(array_Revenue,array_Profit))

#Predict Values
print(regressionModel.predict(array_Revenue))

#Coeficent of Determination
print(regressionModel.score(array_Revenue,array_Profit))

#Y intercept
intercept = regressionModel.intercept_
print(intercept)

#Slope
slope = regressionModel.coef_
print(slope)

print(Independent_x2)

x = np.linspace(-1000,600000,100)
y = (slope*x+intercept)

plt.scatter(Independent_x,Dependent_y, label=str(2021))
plt.scatter(Independent_x2,Dependent_y2, label=str(2021))
plt.plot(array_Revenue,regressionModel.predict(array_Revenue))
plt.plot(x,y)
plt.title("Expenses Against Profits 2021-2022 Tech")
plt.xlabel("Expenses in Millions")
plt.ylabel("Profits in Millions")
plt.annotate('R2 score = %(score)d  ' %{"score":score}, xy = (0,155000))
plt.legend(loc = 0, numpoints = 1, ncol = 2, fontsize = 8)
plt.show()
# Out:
# 110241.22727272728
# 19811.5
# LinearRegression()
# [11910.83333333 19811.5       ]
# 1.0
# -33360.689163245945
# [0.48232581]
# 1     436458.0
# 2     271137.0
# 7     181604.0
# 8     242767.0
# 12    148783.0
# 13    106817.0
# 22    111548.0
# 26     78559.0
# 27    102226.0
# 30    101432.0
# 45     59156.0
# 47     80716.0
# 48     66601.0
# 54     60729.0
# 57     60524.0
# 58     56984.0
# 59     66488.0
# 64     48304.0
# 68     47028.0
# 73     39227.0
# 90     26733.0
# 91     31486.0
# Name:  Expenses , dtype: float64

# %%
### Comparing Non-Tech Expenses to Profit

#Import Necessary Libraries and Packages
import numpy as np 
import pandas as pd  
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

#Read the Fortune 100 2021 CSV File
df = pd.read_csv("Consolidated 2021 Fortune 100 Company Data.csv", header=0)

#Drop Unnecessary Columns
df = df.drop([' Rank ',' Name ',' Source '], axis = 1)

#Filter Tech Data
df = df[df[" Group "] == "No"]

#Drop Group "Yes"
df = df.drop([' Group '], axis = 1)


#Columns to Be Analyzed
Independent_x = df[' Expenses ']
Dependent_y = df[' Profit ']


#Remove Dollar Signs, Commas, and Spaces From Strings
Independent_x = df[' Expenses '] = df[' Expenses '].str.replace('$', '')
Independent_x = df[' Expenses '] = df[' Expenses '].str.replace(' ', '')
Independent_x = df[' Expenses '] = df[' Expenses '].str.replace(',', '')

Dependent_y = df[' Profit '] = df[' Profit '].str.replace('$', '')
Dependent_y = df[' Profit '] = df[' Profit '].str.replace(' ', '')
Dependent_y = df[' Profit '] = df[' Profit '].str.replace(',', '')
Dependent_y = df[' Profit '] = df[' Profit '].str.replace('(', '-')
Dependent_y = df[' Profit '] = df[' Profit '].str.replace(')', '')


#Convert Data Type to a Float
Independent_x = Independent_x.astype(float)
Dependent_y = Dependent_y.astype(float)

#Take the Average of the Panda DataFrame For Tech
revenueMean_2021 = Independent_x.mean()
profitMean_2021 = Dependent_y.mean()

#Read the Fortune 100 2022 CSV File
df2 = pd.read_csv("Consolidated 2022 Fortune 100 Company Data.csv", header=0)

#Drop Unnecessary Columns
df2 = df2.drop([" Rank ", " Name "," Source "], axis = 1)

#Filter Tech Data
df2 = df2[df2[' Tech '] == "No"]

#Drop Group "Yes"
df2 = df2.drop([' Tech '], axis = 1)


#Columns to Be Analyzed
Independent_x2 = df2[' Expenses ']
Dependent_y2 = df2[' Profit ']


#Remove Dollar Signs, Commas, and Spaces From Strings
Independent_x2 = df2[' Expenses '] = df2[' Expenses '].str.replace('$', '')
Independent_x2 = df2[' Expenses '] = df2[' Expenses '].str.replace(' ', '')
Independent_x2 = df2[' Expenses '] = df2[' Expenses '].str.replace(',', '')

Dependent_y2 = df2[' Profit '] = df2[' Profit '].str.replace('$', '')
Dependent_y2 = df2[' Profit '] = df2[' Profit '].str.replace(' ', '')
Dependent_y2 = df2[' Profit '] = df2[' Profit '].str.replace(',', '')
Dependent_y2 = df2[' Profit '] = df2[' Profit '].str.replace('(', '-')
Dependent_y2 = df2[' Profit '] = df2[' Profit '].str.replace(')', '')

#Convert Data Type to a Float
Independent_x2 = Independent_x2.astype(float)
Dependent_y2 = Dependent_y2.astype(float)

#Take the Average of the Panda DataFrame For Tech
revenueMean_2022 = Independent_x2.mean()
profitMean_2022 = Dependent_y2.mean()

print(revenueMean_2022)
print(profitMean_2022)

array_Revenue = []
array_Profit = []

array_Revenue.append(revenueMean_2021)
array_Revenue.append(revenueMean_2022)
array_Revenue = np.array(array_Revenue).reshape((-1,1))


array_Profit.append(profitMean_2021)
array_Profit.append(profitMean_2022)
array_Profit = np.array(array_Profit)

#Implement the Linear Regression Function
regressionModel = LinearRegression()


#Fit the Model
print(regressionModel.fit(array_Revenue,array_Profit))

#Predict Values
print(regressionModel.predict(array_Revenue))

#Coeficent of Determination
print(regressionModel.score(array_Revenue,array_Profit))

#Y intercept
intercept = regressionModel.intercept_
print(intercept)

#Slope
slope = regressionModel.coef_
print(slope)

print(Independent_x2)

x = np.linspace(-1000,600000,100)
y = (slope*x+intercept)

plt.scatter(Independent_x,Dependent_y, label=str(2021))
plt.scatter(Independent_x2,Dependent_y2, label=str(2022))
plt.plot(array_Revenue,regressionModel.predict(array_Revenue))
plt.plot(x,y)
plt.title("Expenses Against Profit 2021-2022 Non-Tech")
plt.xlabel("Expenses in Millions")
plt.ylabel("Profits in Millions")
plt.annotate('R2 score = %(score)d  ' %{"score":score}, xy = (0,155000))
plt.legend(loc = 0, numpoints = 1, ncol = 2, fontsize = 8)
plt.show()
# Out:
# 86784.16666666667
# 9298.637179487181
# LinearRegression()
# [4020.44736842 9298.63717949]
# 1.0
# -69803.8297514933
# [0.91148501]
# 0     559081.0
# 3     284201.0
# 4     270312.0
# 5     262600.0
# 6     186299.0
#         ...
# 95     34170.0
# 96     35773.0
# 97     29656.0
# 98     34641.0
# 99     35580.0
# Name:  Expenses , Length: 78, dtype: float64
